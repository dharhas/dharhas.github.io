# %% [markdown]
# So as a simple test of my new blog I decided to recreate a plot of historical Texas lake storage from [waterdatafortexas](http://waterdatafortexas.org). The original plot can be seen below:

# %%
# %pylab inline
from IPython.display import Image
import pandas as pd
#plt.xkcd()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
Image('http://waterdatafortexas.org/reservoirs/statewide/historical-storage.png')

# %%
data = pd.read_csv('http://waterdatafortexas.org/reservoirs/statewide.csv', skiprows=29, index_col='date', parse_dates=True)

# %%
data['conservation_storage'].plot()

# %%
plt.xkcd()

# %%
data['conservation_storage'].plot()
